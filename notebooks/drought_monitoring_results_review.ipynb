# %% [markdown]
# # Northern Nigeria Drought Monitoring — Results Review
# Loads the published trend and hotspot tables.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
regional = pd.read_csv(ROOT / 'data/processed/tables/regional_mann_kendall_sen_slope_trends_2001_2025.csv')
regional

# %%
pressure = pd.read_csv(ROOT / 'data/processed/tables/state_integrated_climate_vegetation_pressure_ranking.csv')
pressure[['Rank','State','Geo_Zone','Integrated_Pressure_Score','Pressure_Class']].head(10)
